# %%
import numpy, pandas

# %%
df = pandas.read_csv('AirWeBreathe.csv')
pandas.set_option('display.max_rows', 1000)
display(df)
# Out:
#     Daily Mean data\t    supplied by UK-air on 28/06/2020          Unnamed: 1  \
# 0                             All Data GMT hour ending                    NaN
# 1    Status: V=Verified P=Provisionaly Verified N=N...                    NaN
# 2                                                  NaN     Bristol Temple Way
# 3                                                 Date       Nitrogen dioxide
# 4                                           01/02/2020                     16
# 5                                           02/02/2020                     20
# 6                                           03/02/2020                     25
# 7                                           04/02/2020                     31
# 8                                           05/02/2020                     61
# 9                                           06/02/2020                     63
# 10                                          07/02/2020                     34
# ...

# %%
i=4 #initial index of measurment data
f=len(df) #final index of measurment data
sf=df[i:f].dropna() #dropping any values with NaN value
sf.reset_index(drop=True, inplace=True) #reindexing dataframe
display(sf)
# Out:
#     Daily Mean data\t    supplied by UK-air on 28/06/2020 Unnamed: 1  \
# 0                                           01/02/2020            16
# 1                                           02/02/2020            20
# 2                                           03/02/2020            25
# 3                                           04/02/2020            31
# 4                                           05/02/2020            61
# 5                                           06/02/2020            63
# 6                                           07/02/2020            34
# 7                                           08/02/2020            15
# 8                                           09/02/2020             5
# 9                                           10/02/2020            16
# 10                                          11/02/2020            18
# 11                                          12/02/2020            28
# 12                                          13/02/2020            31
# ...
